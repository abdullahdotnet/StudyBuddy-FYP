# %%
import os
import pandas as pd
from dotenv import load_dotenv

# %%
# Load environment variables
load_dotenv()
groq_api_key = os.getenv('GROQ_API_KEY')
if not groq_api_key:
    raise ValueError("GROQ API key not found in .env file")

os.environ["GROQ_API_KEY"] = groq_api_key
# BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
BASE_DIR = os.getcwd()

# %%
# Function to load all CSV files from input_data folder
def load_data_from_files(folder_path):
    csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    all_data = pd.DataFrame()
    
    # Load each CSV file and concatenate
    for file in csv_files:
        file_path = os.path.join(folder_path, file)
        paper_data = pd.read_csv(file_path)
        all_data = pd.concat([all_data, paper_data], ignore_index=True)
        all_data = all_data.dropna()
    return all_data

# %% [markdown]
# # Creating Rag Chains for different subjects

# %%
import pickle
import re

# imports for creating pipeline for rag
from langchain.embeddings import HuggingFaceEmbeddings      # for embeddings
from langchain.vectorstores import Chroma                  # for vector store
from langchain.document_loaders import TextLoader        # for loading text
from langchain.text_splitter import RecursiveCharacterTextSplitter  # acting as base class for splitting text 
from langchain_groq import ChatGroq                         # for initializing LLM from groq
from langchain.schema import Document                   # converting simple text to document object

# For compressing the context of retrieved documents
from langchain.retrievers import ContextualCompressionRetriever     # for compressing retrieved documents context
from langchain.retrievers.document_compressors import LLMChainExtractor     # used in compression

# For creating the retrieval chain for chat history
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# For creating history aware retriever
from langchain.chains import create_history_aware_retriever
from langchain_core.prompts import MessagesPlaceholder
from langchain_core.messages import AIMessage, HumanMessage     # for messages in history aware retriever

# %%
embedding_model = None
documents = None
text_splitter = None
split_docs = None
vector_store = None
embedded_docs = None
llm = None
retriever = None
contextualize_q_system_prompt = None
contextualize_q_prompt = None
history_aware_retriever = None
system_prompt = None
qa_prompt = None
question_answer_chain = None
book_file_path = 'input_data/9thComputerScience_cleaned.txt'

# %%
def initialize_embeddings_model():
    global embedding_model
    if embedding_model is None:
        embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")


# Load the Text Data and Create Documents
def load_documents(file_path):
    loader = TextLoader(file_path,encoding='utf-8')
    documents = loader.load()
    return documents

# Custom RecursiveCharacterTextSplitter with regex patterns for subtopics and chapters
class CustomTextSplitter(RecursiveCharacterTextSplitter):
    def __init__(self, **kwargs):
        subtopic_pattern = re.compile(r'(\d+(\.\d+)+)')
        chapter_separator = 'chapter end -------------------------------------'

        # Initialize with any other parameters, and add your separators
        super().__init__(separators=[chapter_separator], **kwargs)
        self.subtopic_pattern = subtopic_pattern

    def split_text(self, text):
        # First, split by chapters
        texts = super().split_text(text)
        documents = []
        
        # For each chapter, split by subtopic using the subtopic regex
        chapter_number = 1
        for chapter in texts:
            subtopic_splits = self._split_by_subtopic(chapter, chapter_number)
            documents.extend(subtopic_splits)
            chapter_number += 1
        
        return documents

    def _split_by_subtopic(self, text, chapter_number):
        # Use the subtopic regex to split text
        matches = list(self.subtopic_pattern.finditer(text))
        if not matches:
            # No subtopics found, return the full text as a single Document
            return [Document(page_content=text.strip(), metadata={"chapter": chapter_number})]
        
        subtopics = []
        start_idx = 0
        subtopic_number = 1
        
        for match in matches:
            end_idx = match.start()
            if start_idx != end_idx:
                subtopics.append(Document(
                    page_content=text[start_idx:end_idx].strip(),
                    metadata={"chapter": chapter_number, "subtopic": subtopic_number}
                ))
            start_idx = end_idx
            subtopic_number += 1
            
        # Append the remaining part as a subtopic
        subtopics.append(Document(
            page_content=text[start_idx:].strip(),
            metadata={"chapter": chapter_number, "subtopic": subtopic_number}
        ))
        
        return subtopics

# Create embeddings and handle storage
def embed_documents(split_docs, embedding_model):
    EMBEDDINGS_FOLDER = "entrytest\\embeddings"
    EMBEDDINGS_FILE = os.path.join(EMBEDDINGS_FOLDER, "9thComputerScience.pkl")

    if not os.path.exists(EMBEDDINGS_FOLDER):
        os.makedirs(EMBEDDINGS_FOLDER)

    if os.path.exists(EMBEDDINGS_FILE):
        print(f"Loading existing embeddings from {EMBEDDINGS_FILE}...")
        with open(EMBEDDINGS_FILE, 'rb') as f:
            embedded_docs = pickle.load(f)
            print("Embeddings loaded successfully.")
    else:
        print("Creating new embeddings...")
        texts = [doc.page_content for doc in split_docs]
        embedded_docs = embedding_model.embed_documents(texts)

        with open(EMBEDDINGS_FILE, 'wb') as f:
            pickle.dump(embedded_docs, f)
            print(f"Embeddings saved to {EMBEDDINGS_FILE}")

    return embedded_docs

# Store embeddings in Chroma vector store
def store_embeddings(split_docs, embedding_model):
    vector_store = Chroma.from_documents(split_docs, embedding_model) 
    return vector_store

def getting_retriever(llm,vector_store):
    """Opiton 01: Creating ContextualCompressionRetriever
    Contextual Compression will find the relevant records and only contains the relevant data from chunks instead of whole chunks
    Maximum Marginal Relevance (mmr) is used to get diverse set of documents.
    Option 02: SelfQueryRetrieval for filtering based on sources"""
    # Option 01
    compressor = LLMChainExtractor.from_llm(llm)
    compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor,
    base_retriever=vector_store.as_retriever(search_kwargs={"k": 10})
    #search_type = "mmr"
    )
    return compression_retriever

# Initialize the LLM
def initialize_llm(model_name="llama-3.1-70b-versatile", temperature=0):
    llm = ChatGroq(
        model= model_name,
        temperature=temperature,
    )
    return llm

def initialize_documents(book_file_path):
    global documents
    # Load your document
    documents = load_documents(book_file_path)
def initialize_text_splitter():
    global text_splitter
    text_splitter = CustomTextSplitter(chunk_size=1000, chunk_overlap=0)

def intialize_split_docs():
    global split_docs, documents, text_splitter
    split_docs = text_splitter.split_text(documents[0].page_content)

def initialize_vector_store():
    global vector_store, split_docs, embedding_model
    vector_store = store_embeddings(split_docs, embedding_model)
def initialize_embedded_docs():
    global embedded_docs, split_docs, embedding_model
    embedded_docs = embed_documents(split_docs, embedding_model)

def initialize_chat_llm():
    global llm
    llm = initialize_llm()

def initialize_retriever():
    # Create the retriever having contextual compression
    global retriever, llm, vector_store
    retriever = getting_retriever(llm, vector_store)

def initialize_contextualize_q_system_prompt():
    global contextualize_q_system_prompt
    contextualize_q_system_prompt = (
        "Act as a conversational assistant similar to ChatGPT. Engage in natural dialogue and answer questions based on the context provided through the chat history or retrieved using Retrieval-Augmented Generation (RAG). If the relevant context is not found either in the conversation or via RAG, respond by stating that the information is unavailable or ask for more clarification from the user. Do not provide speculative or out-of-context information. Always ensure responses are precise and contextually relevant."
    )

def initialize_contextualize_q_prompt():
    global contextualize_q_prompt
    contextualize_q_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", contextualize_q_system_prompt),
            MessagesPlaceholder("chat_history"),
            ("human", "{input}"),
        ]
    )

def initialize_history_aware_retriever():
    # Creating a new retirever that is aware of the chat history. Rest of the things are same.
    global llm, retriever, contextualize_q_prompt, history_aware_retriever
    history_aware_retriever = create_history_aware_retriever(
        llm, retriever, contextualize_q_prompt
    )

def initialize_system_prompt():
    global system_prompt
    system_prompt = (
        "Act as a conversational assistant similar to ChatGPT. Engage in natural dialogue and answer questions based on the context provided through the chat history or retrieved using Retrieval-Augmented Generation (RAG). If the relevant context is not found either in the conversation or via RAG, respond by stating that the information is unavailable or ask for more clarification from the user. Do not provide speculative or out-of-context information. Always ensure responses are precise and contextually relevant."
        "\n\n"
        "{context}"
    )

def initialize_qa_prompt():
    global qa_prompt
    qa_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            ("human", "{input}"),
        ]
    )

def initialize_question_answer_chain():
    global llm, qa_prompt, question_answer_chain
    question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)

# %%
class RAGChainInitializer:
    _instance = None
    _rag_chain = None

    def __new__(cls):
        if cls._instance is None:
            cls._instance = super(RAGChainInitializer, cls).__new__(cls)
        return cls._instance

    def initialize_chain(self, book_file_path):
        if self._rag_chain is None:
            initialize_embeddings_model()
            initialize_documents(book_file_path)
            initialize_text_splitter()
            intialize_split_docs()
            initialize_vector_store()
            initialize_chat_llm()
            initialize_retriever()
            initialize_system_prompt()
            initialize_qa_prompt()
            initialize_question_answer_chain()
            self._rag_chain = create_retrieval_chain(retriever, question_answer_chain)
        return self._rag_chain

# usage
def create_rag_chain(book_file_path):
    initializer = RAGChainInitializer()
    return initializer.initialize_chain(book_file_path)

# %%
rag_chain = create_rag_chain('input_data/9thComputerScience_cleaned.txt')
# Out:
# c:\Users\zubay\.conda\envs\fyp\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
result = rag_chain.invoke({"input": "can you give me an interesting topic from 1st chapter"})
result
# Out:
# {'input': 'can you give me an interesting topic from 1st chapter',
#  'context': [Document(metadata={'chapter': 1, 'subtopic': 2}, page_content='1.1 Problem Solving Steps\nIn order to solve a problem, it is important to follow a systematic approach. In the following we discuss different steps that we can follow to solve a problem systematically.'),
#   Document(metadata={'chapter': 1, 'subtopic': 2}, page_content='1.1 Problem Solving Steps\nIn order to solve a problem, it is important to follow a systematic approach. In the following we discuss different steps that we can follow to solve a problem systematically.')],
#  'answer': 'Based on the provided text, it seems like we\'re discussing the topic of "Problem Solving Steps" from the 1st chapter. \n\nA potentially interesting topic from this chapter could be the actual steps involved in solving a problem systematically. Unfortunately, the provided text doesn\'t go into detail about the specific steps. However, I can try to provide some general information on this topic.\n\nTypically, problem-solving steps include:\n\n1. Identifying the problem\n2. Analyzing the problem\n3. Generating possible solutions\n4. Evaluating the solutions\n5. Implementing the chosen solution\n6. Reviewing and refining the solution\n\nIf you\'d like to know more about these steps or have any specific questions, feel free to ask!'}

# %%
result = rag_chain.invoke({"input": "can you give concise answer of previous question"})
result
# Out:
# {'input': 'can you give concise answer of previous question',
#  'context': [],
#  'answer': "There is no previous question to provide an answer for. This conversation has just started. Please feel free to ask a question, and I'll do my best to provide a concise answer."}

# %%
# Define the number of questions for each subject
subjects_questions = {
    "Biology": 68,
    "Chemistry": 54,
    "Physics": 54,
    "English": 18,
    "Logical Reasoning": 6
}

# Load all data from input_data folder
# data_folder = os.path.join(BASE_DIR, 'entrytest/input_data')
data_folder = 'input_data'
data = load_data_from_files(data_folder)

# Sample questions for each subject
biology_questions = data[data['Subject'] == 'Biology'].sample(n=subjects_questions["Biology"])
chemistry_questions = data[data['Subject'] == 'Chemistry'].sample(n=subjects_questions["Chemistry"])
physics_questions = data[data['Subject'] == 'Physics'].sample(n=subjects_questions["Physics"])
english_questions = data[data['Subject'] == 'English'].sample(n=subjects_questions["English"])
logical_reasoning_questions = data[data['Subject'] == 'Logical Reasoning'].sample(n=subjects_questions["Logical Reasoning"])
# Combine the sampled questions while maintaining subject order
combined_questions = pd.concat([
    biology_questions, chemistry_questions, 
    physics_questions, english_questions, 
    logical_reasoning_questions
])
# Assign sequential IDs to the questions
combined_questions['ID'] = range(1, len(combined_questions) + 1)
# Convert to a list of dictionaries for the response
mcq_paper = []
answer_map = {
        'A': 0,
        'B': 1,
        'C': 2,
        'D': 3
    }
for _, item in combined_questions.iterrows():
    mcq_paper.append({
        "id": item['ID'],
        "question": item['Question'],
        "options": [
            item['Option 1'],
            item['Option 2'],
            item['Option 3'],
            item['Option 4']
        ],
        "subject": item['Subject'],
        "answer": answer_map[item['Answers']],
    })

# %%
mcq_paper
# Out:
# [{'id': 1,
#   'question': 'Which of the following is a muscle component that act as store for energy?',
#   'options': ['Myoglobin', 'Creatine-PO4', 'ATP', 'Creatinine-PO4'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 2,
#   'question': 'Most of the monosaccharides form a ring structure when in solution. For example ribose will form a five cornered ring known as:',
#   'options': ['Ribofuranose',
#    'Acetaldehyde',
#    'Glucopyranose',
#    'Glyceraldehyde'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 3,
#   'question': 'Zinc ion attached at the active site of the enzyme carboxypeptidase. The zinc ion functions are',
#   'options': ['An activator',
#    'A coenzyme molecule',
#    'An inhibitor molecule',
#    'Controller or Allosteric site'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 4,
#   'question': 'Only those genes can assort independently whose loci are on:',
#   'options': ['Homologous chromosomes',
#    'Same chromosomes',
#    'Non-homologous chromosomes',
#    'Same chromatids'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 5,
#   'question': 'Cyclosis and amoeboid movements are due to:',
#   'options': ['Microfilaments',
#    'Intermediate filaments',
#    'Cilia',
#    'Microtubule'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 6,
#   'question': 'Nitrifying bacteria are the example of',
#   'options': ['Heterotrophic bacteria',
#    'Parasitic bacteria',
#    'Saprotrophic bacteria',
#    'Chemosynthetic bacteria'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 7,
#   'question': 'Cell wall of prokaryotic cell is composed of:',
#   'options': ['Carbohydrates',
#    'Proteins & Lipids',
#    'Carbohydrates & Proteins',
#    'Proteins'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 8,
#   'question': 'Which statement is true about regarding both starch and cellulose',
#   'options': ['They are geometric isomers of each other',
#    'They are both polymers of glucose',
#    'They are both used for energy storage in plants',
#    'They can both be digested by humans'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 9,
#   'question': 'What does the term bacteriophage refer to',
#   'options': ['A Virus that infect virus',
#    'A virus which behaves as bacteria',
#    'A Virus that infects bacteria',
#    'Combination of bacterium & virion'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 10,
#   'question': 'According to the Biogenetic law of Ernst Haeckel',
#   'options': ['There is use and disuse of organs',
#    'Phylogeny recapitulates ontogeny',
#    'There is survival of the fittest',
#    'Ontogeny recapitulates phylogeny'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 11,
#   'question': 'NAD is an important',
#   'options': ['Vitamin', 'Coenzyme', 'Hormone', 'Enzyme'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 12,
#   'question': 'Which of the following is a conjugated molecule?',
#   'options': ['Glycoproteins', 'Protein', 'Vitamins', 'Lipid'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 13,
#   'question': 'The enzymes integrase, protease and reverse transcriptase are found in which virus',
#   'options': ['Hepatitis A virus',
#    'Human immunodeficiency virus',
#    'Herpes virus',
#    'Influenza virus'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 14,
#   'question': 'Energy is by the breakdown of complex molecules into simpler ones, such reactions are called catabolic reactions',
#   'options': ['Destroyed', 'Consumed', 'Released', 'Produced'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 15,
#   'question': 'Number of major layer/layers of cell wall in gram positive bacteria is/are:Note: This question was deleted',
#   'options': ['1', '2', '4', '3'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 16,
#   'question': 'Which enzyme is different from others',
#   'options': ['Pepsin', 'Trypsin', 'Chymotrypsin', 'Lactase'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 17,
#   'question': 'The chemical messengers that transmit action potential across the synapse in the form of chemicals are',
#   'options': ['Neurotransmitters',
#    'Reflex actions',
#    'Acetylcholinesterase',
#    'Synaptic knob of synapse'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 18,
#   'question': 'Which of the following statement is correct ?',
#   'options': ['Pneumonia is a lung disease caused by Gram Negative bacteria',
#    'Tuberculosis and pneumonia are caused by Gram Positive bacteria',
#    'Tuberculosis is a lung disease caused by Gram Negative bacteria',
#    'Tuberculosis and pneumonia are caused by Gram Negative bacteria'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 19,
#   'question': 'Which of the following type of organs are supposed to be functional in ancestral species rather than in present day species:',
#   'options': ['Vestigial organs',
#    'Embryonic organs',
#    'Homologous organs',
#    'Analogous organs'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 20,
#   'question': 'Feeding by living in or on the other organic (host) belonging to different species is called',
#   'options': ['Mineral nutrition',
#    'Parasitic nutrition',
#    'Saprophytic nutrition',
#    'Symbiotic nutrition'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 21,
#   'question': 'What is FALSE about cartilage?',
#   'options': ['It is a form of connective tissue',
#    'There are many blood vessels in in cartilage',
#    'It is much softer than bone',
#    'It covers ends of the bones at joints'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 22,
#   'question': 'Which one of the following is X Linked Dominant disorder',
#   'options': ['Hypertrichosis',
#    'Color blindness',
#    'Hypophosphatemic rickets',
#    'Haemophilia'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 23,
#   'question': 'Silver fish is a / an',
#   'options': ['Jawless fish', 'Insect', 'Mollusca', 'Cartilaginous fish'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 24,
#   'question': 'Unique three-dimensional shape of the fully folded polypeptide, constitutes',
#   'options': ['Tertiary structure of protein',
#    'Quaternary structure of protein',
#    'secondary structure of protein',
#    'Primary structure of protein'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 25,
#   'question': 'Excretion in Planaria takes place by',
#   'options': ['Metanephridia',
#    'Malpighian tubules',
#    'Protonephridia',
#    'Nephron'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 26,
#   'question': 'A hormone that plays a major role in social bonding, childbirth, milk ejection and sexual reproduction is',
#   'options': ['Prolactin', 'Secretin', 'Estrogen', 'Oxytocin'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 27,
#   'question': 'DNA store biological information in discrete units termed as',
#   'options': ['Karyotype', 'Genes', 'Phenotype', 'Cells'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 28,
#   'question': 'The division of cocci in three planes form sarcina, which is a cube of _____ cocci?',
#   'options': ['8', '4', '2', '16'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 29,
#   'question': 'Hormone produced by placenta is:',
#   'options': ['LH', 'Testosterone', 'FSH', 'Progesterone'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 30,
#   'question': 'Which of the following is a prokaryote?',
#   'options': ['Amoeba', 'E.coli', 'Fungi', 'Protista'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 31,
#   'question': '_____ forms almost three-fourth of the body by weight',
#   'options': ['Water', 'Protein', 'Carbohydrates', 'Lipid'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 32,
#   'question': 'Adaptations that an organism acquires by its own actions during its life span without modifying its genome are',
#   'options': ['Can be made heritable through some modification',
#    'Heritable',
#    'Sometimes heritable and other times non-heritable',
#    'Non-heritable'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 33,
#   'question': 'Round worms belongs to which phylum',
#   'options': ['Nematoda', 'Coelenterata', 'Platyhelminthes', 'Annelida'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 34,
#   'question': 'Virus is what type of agent',
#   'options': ['Non-infectious agent',
#    'Infectious agent',
#    'Non-Protein agent',
#    'Cellular agent'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 35,
#   'question': 'Which cells in male in the human males are responsible for the release of testosterone',
#   'options': ['Hypothalamus',
#    'Pituitary gland',
#    'Leydig cells or interstitial cells',
#    'Sertoli cells'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 36,
#   'question': 'One a.m.u stands for',
#   'options': ['1 atom of all the elements',
#    '1/12th of a carbon',
#    '1/12th of H',
#    'An atom of C-12'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 37,
#   'question': 'Flow of blood in the adjusted by?',
#   'options': ['Pre-capillary sphincters',
#    'Meta-arteriole',
#    'Heart directly',
#    'Valves'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 38,
#   'question': 'Movement of molecules against the concentration gradient is',
#   'options': ['Filtration',
#    'Facilitated transport',
#    'Active transport',
#    'Passive transport'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 39,
#   'question': 'The lymphatic vessels of the body empty the lymph into blood stream at?',
#   'options': ['Subclavian vein',
#    'Jugular vein',
#    'Bile duct',
#    'Abdominal vein'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 40,
#   'question': 'The respiratory surface exhibit following characteristic?',
#   'options': ['It must be non-vascularized',
#    'It must be thick for low diffusion',
#    'It must be permeable',
#    'It should have low ventilation mechanism'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 41,
#   'question': 'The neurotransmitter active outside the CNS (Central Nervous System) is:',
#   'options': ['Glutamate', 'Acetylcholine', 'Serotonin', 'Dopamine'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 42,
#   'question': 'To study sex linkages in drosophila, Morgan mated white eyed males with wild type red eyed females. What will be the phenotype of offspring?',
#   'options': ['White eyed females and red eyed males',
#    'Red eyed females and white eyed males',
#    'All white eyed females and males',
#    'All red eyed males and females'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 43,
#   'question': 'Which of the following virus contains single stranded DNA',
#   'options': ['Parvo virus', 'Pox virus', 'Herpes virus', 'Adeno virus'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 44,
#   'question': 'All the following are disinfectants to control bacterial growth except:',
#   'options': ['Hydrogen Peroxide',
#    'Potassium Permanganate',
#    'Tincture of Iodine',
#    'Mercuric Chloride'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 45,
#   'question': 'What is the best physiological pH for optimum functioning for most of the cellular enzyme of human?',
#   'options': ['6-8 pH', '3-5 pH', '8-10 pH', '2-3 pH'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 46,
#   'question': 'Out of 36 ATPs, how many are produced in electron transport chain',
#   'options': ['28', '32', '34', '30'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 47,
#   'question': 'In a typical nerve, the action potential duration is:',
#   'options': ['1 second', '1 millisecond', '1 microsecond', '1 minute'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 48,
#   'question': 'Competitive inhibitors are _____ .',
#   'options': ['Analogous A substrate',
#    'Smaller than substrate',
#    'Larger than substrate',
#    'Homologous to substrate'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 49,
#   'question': 'Test cross is made to check the genotype of a trait. Which of the following crosses is a test cross ?',
#   'options': ['Unknown X At', 'Unknown X AB', 'Unknown X TT', 'Unknown X tt'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 50,
#   'question': 'Enzymes lower the activation energy by stabilizing the transition state of a metabolic reaction due to',
#   'options': ['Distorting the molecules in the allosteric site',
#    'Changing conditions within the active site',
#    'Changing condition with within the protein framework',
#    'Rearranging the fatty acid in active site'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 51,
#   'question': 'Which of the following is NOT a consequence of anaerobic respiration in humans muscles cells ?',
#   'options': ['High consumption of energy', 'Tiredness', 'Cramps', 'Pain'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 52,
#   'question': 'Water vascular system or ambulacral system is a unique and complex system specially present in',
#   'options': ['Sponges', 'Arthropods', 'Echinoderms', 'Fishes'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 53,
#   'question': 'Smooth muscles are found in all mentioned below except:',
#   'options': ['Trachea', 'Bronchioles', 'Bronchi', 'Alveoli'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 54,
#   'question': 'Production of Follicle-stimulating hormone (FSH) and Luteinizing Hormone (LH) from the pituitary gland of female is controlled by:',
#   'options': ['Hypothalamus', 'Uterus', 'Ovary', 'Stimulated follicles'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 55,
#   'question': 'What is color of Chlorophyll-B molecule',
#   'options': ['Yellowish green',
#    'Blueish green',
#    'Reddish green',
#    'Dark green'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 56,
#   'question': 'The method of bringing oxygenated air into contact with a gas exchange surface is called',
#   'options': ['Ventilation',
#    'Respiration',
#    'Photorespiration',
#    'Gas transport'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 57,
#   'question': 'The animal species on Galapagos resembles species living on the',
#   'options': ['Northern Europe',
#    'Great Britain',
#    'North American mainland',
#    'South American mainland'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 58,
#   'question': 'What is true about Oxytocin',
#   'options': ['Perform cellular fun',
#    'Acts on kidney tubules',
#    'Stimulates ICSH',
#    'Dilate milk ducts of mammary glands'],
#   'subject': 'Biology',
#   'answer': 3},
#  {'id': 59,
#   'question': 'Descending aorta is bifurcated into two vessels which on further division from femoral artery that supply blood to high muscles of legs:',
#   'options': ['Iliac artery',
#    'Temporal artery',
#    'Iliac vein',
#    'Sciatic artery'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 60,
#   'question': 'During resting membrane potential condition:',
#   'options': ['Inner surface of neuron is more positive',
#    'Outer surface of neuron is more positive',
#    'Both of these surfaces are equally negative',
#    'Both of these surfaces are equally positive'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 61,
#   'question': 'The molecule used to control virus during infection of animal cell are',
#   'options': ['Histone', 'Serum', 'Antigen', 'Interferon'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 62,
#   'question': 'Four chambered heart with right systemic arch only is present in',
#   'options': ['Birds', 'Amphibians', 'Mammals', 'Reptiles'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 63,
#   'question': 'How many tail fibrils are attached to the end plate of a bacteriophage?',
#   'options': ['2', '4', '6', '8'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 64,
#   'question': '_____ describes how water and dissolved chemicals are carried through the cell wall and intercellular gaps of plants',
#   'options': ['Vacuolar Theory',
#    'Cytoplasmic Theory',
#    'Symplast Theory',
#    'Apoplast Theory'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 65,
#   'question': 'Mode of inheritance in human can be traced through',
#   'options': ['Experimental Mating',
#    'Chi Square Chart',
#    'Probability Analysis',
#    'Pedigree Analysis'],
#   'subject': 'Biology',
#   'answer': 2},
#  {'id': 66,
#   'question': 'Electron transport chain explains;',
#   'options': ['Mechanism of ATP synthesis',
#    'Photophosphorylation',
#    'Photolysis',
#    'Z-scheme'],
#   'subject': 'Biology',
#   'answer': 1},
#  {'id': 67,
#   'question': 'The pressure exerted by a solution separated by a semipermeable membrane from pure water is ____?',
#   'options': ['Soil potential',
#    'Osmotic pressure',
#    'Solute potential',
#    'Solvent potential'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 68,
#   'question': 'Hydrolysis process is a reverse of_____ process',
#   'options': ['Condensation', 'Photolysis', 'Convection', 'Deduction'],
#   'subject': 'Biology',
#   'answer': 0},
#  {'id': 69,
#   'question': 'Competitive inhibitors stop an enzyme from working by:',
#   'options': ['Blocking the active site of the enzyme',
#    'Changing the shape of the enzyme',
#    'Combining with the product of the reaction',
#    'Merging with the substrate instead'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 70,
#   'question': 'Which type of solid is called as atomic solid',
#   'options': ['Metallic solids',
#    'Covalent solids',
#    'Molecular solids',
#    'Ionic solids'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 71,
#   'question': 'Consider the chlorination of methane, the attack of chlorine free radical on methane form methyl free radical occur in?',
#   'options': ['Propagation step',
#    'Last step',
#    'Termination step',
#    'Initiation step'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 72,
#   'question': 'In reversible reaction, when product is removed, the equilibrium shift towards the:',
#   'options': ['No effect',
#    'Product side',
#    'Both side one by one',
#    'Reactant side'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 73,
#   'question': 'The same moles of H2, N2 and 02 are present in 0.1 cc volume at STP. Which one has greatest number of molecules:',
#   'options': ['H2', 'O2', 'N2', 'Number of molecules are equal'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 74,
#   'question': 'In SN1 reactions the correct order of reactivity of alkyl halide is',
#   'options': ['Primary>secondary>tertiary',
#    'Secondary>primary>tertiary',
#    'Tertiary>secondary>primary',
#    'Primary>tertiary >secondary'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 75,
#   'question': 'Under suitable conditions alkanes cannot undergo _____ reactions',
#   'options': ['Hydrogenation', 'Addition', 'Combustion', 'Substitution'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 76,
#   'question': 'In which of the following, oxygen shows fractional oxidation number',
#   'options': ['OF2', 'Cl2O7', 'Na2O2', 'KO2'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 77,
#   'question': 'Select the metal which is extracted from bauxite',
#   'options': ['Mg', 'Ca', 'Al', 'Cu'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 78,
#   'question': 'Mr. Khan mix acetic acid with thionyl chloride. Which product is obtained',
#   'options': ['CH3COCI + SO2 + HCI',
#    'CH3COOCH3 + SO2',
#    'CH3Cl + SO2 + HCl',
#    'CH3Cl + CH3COCl'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 79,
#   'question': 'Alkyl benzene is formed when benzene is treated with an alkyl halide in the presence of anhydrous aluminum chloride. Identity the type of reaction.',
#   'options': ['Friedel-Craft alkylation reaction',
#    'Halogenation',
#    'Friedel-Craft acylation reaction',
#    'Sulphonation'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 80,
#   'question': 'How will be the rate of reaction, if the slope of the curve is greater near the start of the reaction',
#   'options': ['Lesser', 'Equilibrium', 'Greater', 'Constant'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 81,
#   'question': 'The decrease in solubility of the salt in a solution that already contains an ion common to that salt is known as',
#   'options': ['Common ion effect',
#    'Ksp',
#    'Le Chatelier’s principle',
#    'Solubility product'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 82,
#   'question': 'The process of heat flow between hotter and colder gases remains continued until all the molecules have equal',
#   'options': ['Average translational potential energy',
#    'Average rotational kinetic energy',
#    'Average vibrational kinetic energy',
#    'Average translational kinetic energy'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 83,
#   'question': 'Which of the following element has smaller size?',
#   'options': ['Na', 'Li', 'Al', 'K'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 84,
#   'question': 'What are vinyl alcohol and acetaldehyde',
#   'options': ['Chain isomers', 'Metamers', 'Tautomers', 'Position isomers'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 85,
#   'question': 'The electronic configurations of some elements are given below. Recognize the element that belongs to group IIIA',
#   'options': ['1s2 2s2 2p2', '1s2 2s2 2p3', '1s2 2s2 2p1', '1s2 2s2 2p4'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 86,
#   'question': 'Born-Haber cycle is used to determine the lattice energy of ionic compounds. It is the application of',
#   'options': ['Henry’s law',
#    'Hess’s law',
#    'Le Chatelier’s principle',
#    'Common ion effect'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 87,
#   'question': 'Neopentylchloride belongs to which class of alkyl halide?',
#   'options': ['Quaternary alkyl halide',
#    'Primary alkyl halide',
#    'Tertiary alkyl halide',
#    'Secondary alkyl halide'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 88,
#   'question': 'Which of the following sulphate compound is insoluble in water?',
#   'options': ['CaSO4', 'MgSO4', 'BeSO4', 'BaSO4'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 89,
#   'question': 'Which of the following has the highest atomic radius in its period',
#   'options': ['Halogens',
#    'Alkali metals',
#    'Chalcogens',
#    'Alkaline earth metals'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 90,
#   'question': 'A compound of phosphorus oxide has 43.60% of Oxygen. Its empirical formula is',
#   'options': ['P205', 'P203', 'P02', 'P502'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 91,
#   'question': 'The process of heat flow between hotter and colder gases remains continued until all the molecule have equal',
#   'options': ['Average vibrational K.E',
#    'Average transnational K.E',
#    'Average rotational K.E',
#    'Average transnational P.E'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 92,
#   'question': 'If phenol is treated with 3 moles of conc. HNO3 in the presence of H2SO4 what will be the product',
#   'options': ['O-nitro phenol',
#    'O-nitro phenol and P-nitro phenol',
#    'Picric acid',
#    'P-nitro phenol'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 93,
#   'question': 'Dehydration of alcohol gives which of the following product in the presence of H2SO4 at 140 C',
#   'options': ['Ethyl chloride',
#    'Diethyl ether',
#    'Ethyl acetate',
#    'Acetaldehyde'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 94,
#   'question': 'What is the proton (atomic number) of an element that has four unpaired electrons in its ground state',
#   'options': ['22', '6', '14', '26'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 95,
#   'question': 'What is the unit of heat capacity',
#   'options': ['kJ/K', 'kj.mol', 'JK-1', 'kJmol-1'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 96,
#   'question': 'A compound of sodium oxide has 74.2% sodium and 25.8% of oxygen. The empirical formula of the compound is',
#   'options': ['NaO', 'Na2O', 'Na2O2', 'NaO2'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 97,
#   'question': 'After the digestion & before absorption the product of the protein is:',
#   'options': ['Only Amino Acid',
#    'Amino Acid and small polypeptide',
#    'Only ammonia',
#    'Only small polypeptide'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 98,
#   'question': 'Identify which method is used to prepare Alkynes',
#   'options': ['Dehydration of Alcohols In the presence of Al203 at 340-450-degree centigrade',
#    'Electrolysis of dl carboxylic acid salts',
#    'Dehalogenation of Vicinal Dihalides In the presence of methanol',
#    'Dehalogenation of Vicinal Dihalides in the presence of strong base'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 99,
#   'question': 'Which type of forces exist between iodine molecules',
#   'options': ['Dipole-dipole forces',
#    'Non-polar forces',
#    'Dipole-induced dipole forces',
#    'Instantaneous dipole-induced dipole forces'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 100,
#   'question': 'The addition reaction of 2-butene with HBr produces',
#   'options': ['1-bromobutane',
#    '2-bromobutane',
#    '1,3-dibromobutane',
#    '2,3-dibromobutane'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 101,
#   'question': 'Complete oxidation of alcohol gives which of the following',
#   'options': ['Aldehyde', 'Carboxylic acid', 'Alkane', 'Ketone'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 102,
#   'question': 'The precipitation occur if the ionic concentration is',
#   'options': ['More than ksp',
#    'Present in any amount',
#    'Less than ksp',
#    'Equal to ksp'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 103,
#   'question': 'In which pair one has all unpaired d orbitals while other have all paired d orbitals',
#   'options': ['Cr and Fe', 'Cu and Zn', 'Mn and Co', 'Cr and Zn'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 104,
#   'question': 'Which of the following proteins act as carrier of copper in blood plasma?',
#   'options': ['Histone', 'Glycoprotein', 'Ceruloplasmin', 'Hemoglobin'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 105,
#   'question': 'Which of the following term is state function?',
#   'options': ['Sublimation', 'Decomposition', 'Enthalpy', 'Freezing'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 106,
#   'question': 'One can estimate the direction in which equilibrium will shift with help of',
#   'options': ['Law of mass action',
#    'Law of heat of formation',
#    'Mess’s law',
#    'Le Chatelier’s principle'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 107,
#   'question': 'Which gas discharge tube produces lightest canal ray particles?',
#   'options': ['H2', 'Ar', 'Ne', 'He'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 108,
#   'question': 'Which element is used as standard to determine atomic mass of an element',
#   'options': ['P', 'H', 'C', 'Cl'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 109,
#   'question': 'Oxidation number of free magnesium is',
#   'options': ['2', '3', '1', '0'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 110,
#   'question': 'Which one of them is amphoteric in nature',
#   'options': ['Lithium oxide',
#    'Beryllium oxide',
#    'Calcium oxide',
#    'Potassium oxide'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 111,
#   'question': 'Why fluorine has less electron affinity as compared to bromine',
#   'options': ['Seven electrons in outermost shell',
#    'Electronegativity',
#    'Higher ionization energy',
#    'Thick small electronic cloud'],
#   'subject': 'Chemistry',
#   'answer': 1},
#  {'id': 112,
#   'question': 'The appearance of a silver mirror in Tollens’ test indicates the presence of which of the following',
#   'options': ['A ketone', 'An aldehyde', 'An acid', 'An alcohol'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 113,
#   'question': 'An electrochemical cell is based upon which reaction',
#   'options': ['Redox reaction',
#    'Neutralization reaction',
#    'Nuclear reaction',
#    'Acid-base reaction'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 114,
#   'question': 'Freon is commonly known as?',
#   'options': ['A fire extinguisher',
#    'Refrigerant',
#    'Insecticides',
#    'A solvent'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 115,
#   'question': 'According to which scientist, the probability of finding electron at a certain position is possible?',
#   'options': ['De-Broglie', 'Schrodinger', 'Bohr’s', 'Hund’s'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 116,
#   'question': 'What is the molecular formula of pyridine molecule',
#   'options': ['C6H5N', 'C5H5N', 'C6H6N', 'C5H5NH'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 117,
#   'question': 'When phenol reacts with formaldehyde, which of the following product is produced?',
#   'options': ['Hydronium ion', 'Phenoxide ion', 'Oxinium ion', 'Adduct'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 118,
#   'question': 'If we want to raise the temperature of one mole of an ideal gas by one kelvin, we have to provide how much amount of energy?',
#   'options': ['8.314 dm3-atm', '0.0821 dm3-atm', '0.0821 joules', '0.0821 kJ'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 119,
#   'question': 'When food reaches stomach, the action of the following come to an end due to acidic pH?',
#   'options': ['Lipases', 'Hydrolases', 'Amylase', 'Maltase'],
#   'subject': 'Chemistry',
#   'answer': 0},
#  {'id': 120,
#   'question': 'When halogen is removed from alkyl halide a carbocation is formed, identify the most reactive carbocation',
#   'options': ['Tertiary carbocation',
#    'Secondary carbocation',
#    'Primary carbocation',
#    'Methyl carbocation'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 121,
#   'question': 'Which of the following factor does not affect the magnitude of vapor pressure?',
#   'options': ['Size of liquid',
#    'Temperature of liquid',
#    'Amount of liquid',
#    'Intermolecular forces'],
#   'subject': 'Chemistry',
#   'answer': 2},
#  {'id': 122,
#   'question': 'Which of the functional group are present in ethyl acetate',
#   'options': ['Ether group',
#    'Ester group',
#    'Carboxyl group',
#    'Aldehyde group'],
#   'subject': 'Chemistry',
#   'answer': 3},
#  {'id': 123,
#   'question': 'It has been observed that Thorium (90^234)Th is transformed into protactinium (_91^234)Pa after the emissions of_ particle:',
#   'options': ['Alpha', 'Gama', 'Alpha, Beta, Gamma', 'Beta'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 124,
#   'question': 'Two bodies with kinetic energies in the ratio of 4: 1 are moving with equal linear momentum. The ratio of their masses is:',
#   'options': ['1:02', '1:01', '1:04', '4:01'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 125,
#   'question': 'Which of the following is the correct definition of variable velocity',
#   'options': ['Unequal displacements are made in equal intervals of time',
#    'Equal displacements are made in unequal intervals of time',
#    'Unequal distances are covered in equal intervals of time',
#    'Equal displacements are made in equal intervals of time'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 126,
#   'question': 'A low voltage supply with an e.m.f of 20 V and an internal resistance of 1.5 ohm is used to supply power to a heater of resistance 6.5 ohm in a fish tank. What is the power supplied to the water in the fish tank?',
#   'options': ['41 W', '53 W', '50 W', '62 W'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 127,
#   'question': 'The relation between gray and rad is given as:1 Gy = rad',
#   'options': ['0.001', '100', '10', '0.01'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 128,
#   'question': 'An ideal gas has molar specific heat Cp at constant pressure. When the temperature of n moles is increased by ΔT the increase in the internal energy is:',
#   'options': ['n(Cp + R) ΔT', 'n(Cp – R) ΔT', 'n(2Cp + R) ΔT', 'nCp ΔT'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 129,
#   'question': 'An 8.0-kg box slides along a horizontal frictionless floor at 3 m/s and collides with a relatively massless spring that compresses 12 cm before the box comes to a rest. Calculate the retarding force of the spring.',
#   'options': ['300 N', '30 N', '3000 N', '3 N'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 130,
#   'question': 'One radian is analogous to:',
#   'options': ['57°3″', '57°18″', '57°3', '57°18′'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 131,
#   'question': 'If a flywheel is rotating at 3.0 rad/s, the time takes to complete one revolution is about',
#   'options': ['1.3 s', '2.1 s', '1.0 s', '0.067 s'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 132,
#   'question': 'The shortest distance between any two points in phase on a wave is called',
#   'options': ['Frequency', 'Displacement', 'Amplitude', 'Wavelength'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 133,
#   'question': 'Gauss law cannot be used to find which of the following quantity',
#   'options': ['Permittivity',
#    'Charge',
#    'Electric field intensity',
#    'Electric flux density'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 134,
#   'question': 'As per Coulomb’s law, the force of attraction or repulsion between two-point charges is directly proportional to the:',
#   'options': ['Square of the distance between them',
#    'Sum of the magnitude of charges',
#    'Product of the magnitude of charges',
#    'Cube of the distance'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 135,
#   'question': 'The source of magnetic field us',
#   'options': ['An isolated magnetic pole',
#    'Current loop',
#    'Nonmagnetic substance',
#    'Static electric charge'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 136,
#   'question': 'The mechanical waves are not generated by',
#   'options': ['Electric and magnetic fields',
#    'Water',
#    'Coil of spring',
#    'Ropes'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 137,
#   'question': 'If 0.5 T field is applied over an area of 2-meter square which lies at an angle of 60 degree with the field, then the resulting flux will be:',
#   'options': ['0.25 Wb', '0.5 T', '0.25 T', '0.5 Wb'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 138,
#   'question': 'The expression for the emf produced by A.C generator is',
#   'options': ['NωAB SinΘ', 'ILB CosΘ', 'NωAB CosΘ', 'NωAB'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 139,
#   'question': 'The unit of ΔΦ / Δt can be written as ?',
#   'options': ['NmA-1s-1', 'NmAs-1', 'NmA-2s-1', 'NmA-2s1'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 140,
#   'question': 'Electric forces change the magnitude and direction of velocity while magnetic forces change___ of velocity',
#   'options': ['Magnitude and direction',
#    'Neither magnitude nor direction',
#    'Only direction',
#    'Only magnitude'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 141,
#   'question': 'According to maximum power transfer theorem, which of the following is the max power delivered by the battery to the output',
#   'options': ['E^2/3r', 'E^2/4r', 'E^2/5r', 'E^2/2r'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 142,
#   'question': 'Working principal of magnetic levitation train is according to',
#   'options': ['Ohm law', 'Lenz law', 'Max planks law', 'Faraday law'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 143,
#   'question': 'A stone thrown horizontally from top of a tall building follows a path that is',
#   'options': ['Made of two straight line segments',
#    'Hyperbolic',
#    'Circular',
#    'Parabolic'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 144,
#   'question': 'Wave trough refers to the:',
#   'options': ['Wave length',
#    'Lowest point of the wave',
#    'Wave speed',
#    'Highest point of the wave'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 145,
#   'question': '0ne degree is equal to:',
#   'options': ['Π/90 radians',
#    'Π/360 radians',
#    'Π/180 radians',
#    'Π/270 radians'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 146,
#   'question': 'A distant star is receding from Earth with a speed of 1.40 × 10^7 m/s. It emits light of frequency 4.57 × 10^14 Hz. The speed of light is 3.0 × 10^8 m/s. The Doppler effect formula can be used with light waves. What will be the frequency of this light when detected on Earth?',
#   'options': ['4.37 × 10^14 Hz',
#    '4.79 × 10^14 Hz',
#    '2.04 × 10^13 Hz',
#    '4.57 × 10^14 Hz'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 147,
#   'question': 'A capacitor charged with a battery and energy stored is U. After disconnecting battery another capacitor of same capacity is connected in parallel to the first capacitor. Then energy stored in each capacitor is',
#   'options': ['4U', 'U/4', '2U', 'U/2'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 148,
#   'question': 'Working principle of magnetic levitation train is according to?',
#   'options': ['Ohm law', 'Lenz law', 'Faraday law', 'Max planks law'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 149,
#   'question': 'The process of ejection of loosely bound electrons from a certain photo sensitive surface by absorption of photon is called:',
#   'options': ['Pair production',
#    'Compton effect',
#    'Black body radiation',
#    'Photoelectric effect'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 150,
#   'question': 'Velocity selector will select only those charge particles whose velocity is given by:',
#   'options': ['V=ExB', 'V=0', 'V=E/B', 'V=B/E'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 151,
#   'question': 'The speed of sound in an ideal gas depends upon:',
#   'options': ['Frequency and fog',
#    'Temperature and amplitude',
#    'Density and amplitude',
#    'Temperature and density'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 152,
#   'question': 'The circular line has a fix distance from _____ .',
#   'options': ['A fix point',
#    'Any point',
#    'A point on a circle',
#    'A point from outside'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 153,
#   'question': 'The resistance of the wire varies inversely as:',
#   'options': ['Area of cross section', 'Length', 'Resistivity', 'Temperature'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 154,
#   'question': 'Which one of the following statement is true?',
#   'options': ['Electrostatic force obeys inverse square law while gravitational forces does not',
#    'Both electrostatic force and gravitational force doesn’t obey inverse square law',
#    'Gravitational force is much weaker than electrostatic force',
#    'Both gravitational force and electrostatic force are repulsive in nature'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 155,
#   'question': 'Gauss law cannot be used to find which of the following quantity?',
#   'options': ['Charge',
#    'Electric field intensity',
#    'Electric flux density',
#    'Permittivity'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 156,
#   'question': 'The induced emf produced in the coil is sometimes called as:',
#   'options': ['Back emf',
#    'Self-inductance',
#    'Mutual inductance',
#    'Motional emf'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 157,
#   'question': 'What is the potential difference between two points in an electric field if it takes 600 J of energy to move a charge of 2 C between these two points',
#   'options': ['800 J', '1200 J', '0 J', '300 J'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 158,
#   'question': 'Which of the following is the correct definition of variable velocity?',
#   'options': ['Unequal distance are covered in equal intervals of time',
#    'Unequal displacements are made in equal intervals of time',
#    'Unequal distance are covered in unequal intervals of time',
#    'Equal displacements are made in equal intervals of time'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 159,
#   'question': 'Temperature of the given mass of gas is changed from 150 C to 300 C during an barbaric process, volume of the gas will become',
#   'options': ['Less than double', 'Double', 'Half', 'Remain same'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 160,
#   'question': 'In Compton effect, a photon of a certain wavelength collides with a stationary electron. The wavelength of the emitted photon is:',
#   'options': ['Shorter', 'Same', 'Longer', 'Infinite'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 161,
#   'question': 'On which car there is resultant force',
#   'options': ['Car moving at constant speed around a bend',
#    'Car moving uphill at a constant velocity',
#    'Car that is stationary',
#    'Car moving on a straight horizontal road'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 162,
#   'question': 'The quantity Δφ/Δt has the same units as that of',
#   'options': ['Charge', 'Current', 'Emf', 'Magnetic induction'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 163,
#   'question': 'An airplane travels at speed of 0.5v where v is the speed of sound. The airplane approaches a stationary observer. The frequency of sound emitted by the aircraft is 200 Hz. Which frequency does the observer hear?',
#   'options': ['120 Hz', '100 Hz', '180 Hz', '400 Hz'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 164,
#   'question': 'The consumption of energy by a 60 W bulb in 2s is:',
#   'options': ['60 J', '120 J', '30 J', '0.02 J'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 165,
#   'question': 'A 3 V battery is connected in series with ammeter and 2-ohm resistance after short circuiting. What will be the reading of ammeter?',
#   'options': ['1:00 AM', '5:00 AM', '6:00 AM', '1.5 A'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 166,
#   'question': 'The resistance of a conductor does not depend on which of the following?',
#   'options': ['Mass', 'Length', 'Resistivity', 'Area'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 167,
#   'question': 'What do the substances whose resistance decrease with increase in temperature have ?',
#   'options': ['Zero temperature coefficient',
#    'Positive temperature coefficient',
#    'Negative temperature coefficient',
#    'High temperature coefficient'],
#   'subject': 'Physics',
#   'answer': 3},
#  {'id': 168,
#   'question': 'If the wavelength of light coming from a galaxy shifts towards the red end of spectrum, then galaxy is',
#   'options': ['Receding the Earth',
#    'Stationary',
#    'Approaching Earth',
#    'Approaching Earth or is stationary'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 169,
#   'question': 'The half-life of Strontium (Sr) is 8.70 hours. Its decay constant is :',
#   'options': ['0.000032 s', '0.000022 s', '0.000022 s', '45000 s'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 170,
#   'question': 'For the positive half cycle i.e., 0 → T/ 2, the diode D:',
#   'options': ['Is reverse biased',
#    'Shows maximum resistance',
#    'Is forward biased',
#    'Behaves as open'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 171,
#   'question': 'The coulomb’s constant K depend upon:',
#   'options': ['Nature of medium',
#    'Nature of medium and system of units',
#    'Types of charge',
#    'System of units'],
#   'subject': 'Physics',
#   'answer': 2},
#  {'id': 172,
#   'question': 'In a photoelectric effect spectrum, the stopping potential is:',
#   'options': ['The K.E of the most energetic electron ejected',
#    'The P.E of the most energetic electron ejected',
#    'The electric potential that cause the electron current to vanish',
#    'The photon energy'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 173,
#   'question': 'In the displacement-time graph, if the slope is constant then the velocity is',
#   'options': ['Constant',
#    'Variable',
#    'May be variable or constant',
#    'Infinite'],
#   'subject': 'Physics',
#   'answer': 1},
#  {'id': 174,
#   'question': 'A capacitor of capacitance ‘C’ has a charge ‘Q’ and stored energy is ‘w’. If the charge is increased to ‘2Q’. The stored energy will be:',
#   'options': ['4W', 'W/4', 'W/2', '2W'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 175,
#   'question': 'A low energy neutron has RBE factor of 10. How much energy is absorbed by a man of mass 80 kg if the value or equivalent does is 400 rem?',
#   'options': ['16 J', '48 J', '64 J', '32 J'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 176,
#   'question': 'Thermodynamics is that branch of physics in which we study',
#   'options': ['Relations between chemical and mechanical energies',
#    'Relations between heat and mechanical energies',
#    'Relations between heat and ionization energies',
#    'Relations between K.E and P.E energies'],
#   'subject': 'Physics',
#   'answer': 0},
#  {'id': 177,
#   'question': 'Choose the sentence with correct use of the article',
#   'options': ['Natasha can play the piano and the violin.',
#    'Natasha can play piano and violin.',
#    'Natasha can play the piano and a violin.',
#    'Natasha can play a piano and a violin.'],
#   'subject': 'English',
#   'answer': 0},
#  {'id': 178,
#   'question': '_____ methods don’t work. Choose the correct option:',
#   'options': ['This', 'These', 'That', 'The'],
#   'subject': 'English',
#   'answer': 3},
#  {'id': 179,
#   'question': 'We just _____ a game of tennis',
#   'options': ['Had', 'Has', 'Have had', 'Have'],
#   'subject': 'English',
#   'answer': 0},
#  {'id': 180,
#   'question': 'Punctuate the given sentence correctlyMy father is Chairman of the Committee on Internal Relations he also heads the Discipline Committee.',
#   'options': ['My father is Chairman of the Committee on Internal Relations – he also heads the Discipline Committee',
#    'My father is Chairman of the Committee on Internal Relations: he also heads the Discipline Committee',
#    'My father is Chairman of the Committee on Internal Relations. He also heads the Discipline Committee',
#    'My father is Chairman of the Committee on Internal Relations, but he also heads the Discipline Committee'],
#   'subject': 'English',
#   'answer': 2},
#  {'id': 181,
#   'question': 'Which of the following sentence is correct',
#   'options': ['How could Sarah persuade her mum to stay out later?',
#    'How could Sarah parswad her mum to stay out later?',
#    'How could Sarah persuad her mum to stay out later?',
#    'How could Sarah parsuade her mum to stay out later?'],
#   'subject': 'English',
#   'answer': 3},
#  {'id': 182,
#   'question': 'A shoal of fish _____ killed by the fishermen.',
#   'options': ['Have', 'Had', 'Has', 'Has been'],
#   'subject': 'English',
#   'answer': 3},
#  {'id': 183,
#   'question': 'At last the fly was _____ . The most appropriate word to be filled in is:',
#   'options': ['Invited by the spider',
#    'Trapped by the spider',
#    'Spared by the spider',
#    'Entertained by the spider'],
#   'subject': 'English',
#   'answer': 0},
#  {'id': 184,
#   'question': 'Identify the sentence, out of the following, that is error free',
#   'options': ['I do not enjoying being laughed at by other people',
#    'I am not enjoying laughing by other people',
#    'I did not enjoy laughing by other people',
#    'I do not enjoy being laughed at by other people'],
#   'subject': 'English',
#   'answer': 3},
#  {'id': 185,
#   'question': 'Distribute the handouts_____the candidates. The correct preposition to be filled in is',
#   'options': ['Among', 'In', 'Into', 'On'],
#   'subject': 'English',
#   'answer': 1},
#  {'id': 186,
#   'question': 'Choose the most appropriate antonym for “Abandonment “',
#   'options': ['Stoppage', 'Halt', 'Extension', 'Cessation'],
#   'subject': 'English',
#   'answer': 1},
#  {'id': 187,
#   'question': 'Choose the correct optionWe felt as if the ground was _____ beneath our feet.',
#   'options': ['Bursting', 'Sinking', 'Slipping', 'Digging'],
#   'subject': 'English',
#   'answer': 1},
#  {'id': 188,
#   'question': 'To give one some idea of Rabies’ horrors, one  _____ only   read such descriptions as the following: spasms, restlessness, shudders at the least breath of air, an ardent thirst, convulsive movements, and fits of furious age.',
#   'options': ['Needs', 'Has needed', 'Needed', 'Need'],
#   'subject': 'English',
#   'answer': 3},
#  {'id': 189,
#   'question': 'Which one of the following is correct',
#   'options': ['We visited, Istanbul, Turkey, and Kowloon, Hong kong last summer',
#    'We visited Istanbul, Turkey, and Kowloon, Hong kong last summer.',
#    'We visited: Istanbul, Turkey, and Kowloon, Hong kong last summer',
#    'We visited Istanbul, Turkey, Kowloon, Hong kong last summer'],
#   'subject': 'English',
#   'answer': 2},
#  {'id': 190,
#   'question': 'Choose the most suitable/appropriate sentence out of the following',
#   'options': ['Penny did not let me to get my book',
#    'Penny had not left me get my book',
#    'Penny was not leaving me to get my book',
#    'Penny did not let me get my book'],
#   'subject': 'English',
#   'answer': 1},
#  {'id': 191,
#   'question': 'A carpenter carves _____ on cab doors. Choose the right word to fill in the blank.',
#   'options': ['Floral', 'Arabesque', 'Decked', 'Ornate'],
#   'subject': 'English',
#   'answer': 2},
#  {'id': 192,
#   'question': 'Choose the correct sentence',
#   'options': ['This scissor is very sharp',
#    'These scissors are very sharp',
#    'This scissors is very sharp',
#    'These scissor are very sharp'],
#   'subject': 'English',
#   'answer': 2},
#  {'id': 193,
#   'question': 'Choose the similar meaning of the bracketed word. (Providentially), his mind was not injured',
#   'options': ['Steadily', 'Luckily', 'Slowly', 'Really'],
#   'subject': 'English',
#   'answer': 1},
#  {'id': 194,
#   'question': 'Which of the following sentences is correct',
#   'options': ['I want to live near my parents live',
#    'I want to live where my parents live',
#    'I want to live where, my parents live',
#    'I want to live where: my parents live'],
#   'subject': 'English',
#   'answer': 3},
#  {'id': 195,
#   'question': 'Read the following statements and identify the best cause and effect relation.I. State P started providing multiple rehabilitation schemes, like free education, job search help and help groups for addicts, etc. over the past year.II. Crimes rates for state P have steadily decreased over the past year',
#   'options': ['I and II are both effects of independent causes',
#    'I is the cause and II is its effect',
#    'I and II are effects of some common cause',
#    'II is the cause and I is its effect'],
#   'subject': 'Logical Reasoning',
#   'answer': 2},
#  {'id': 196,
#   'question': '“To cut off the head”. Idiom means',
#   'options': ['Urbanite', 'Impaled', 'Decapitate', 'Defrock'],
#   'subject': 'Logical Reasoning',
#   'answer': 2},
#  {'id': 197,
#   'question': 'Right after the Civil War, many distraught soldiers made their way West to find fame and Some could not go home because there were no homes to go to. The war had devastated rent One young man, Will Goodlad, made his fortune in the hills of Colorado. He found gold in a idle river near Grand Junction. His fortune was short lived, however. In 1875, he declared bankruptcy and returned to the land of his birth- the Piedmont of South Carolina. For which side did will fight during the War.',
#   'options': ['South', 'West', 'North', 'East'],
#   'subject': 'Logical Reasoning',
#   'answer': 2},
#  {'id': 198,
#   'question': 'Observe the pattern and select the next term in the sequence: SSSSS, SSRSS, SRQRS, RQPQR',
#   'options': ['QRORQ', 'RQPOPQR', 'QPOPQ', 'RQOQR'],
#   'subject': 'Logical Reasoning',
#   'answer': 0},
#  {'id': 199,
#   'question': 'Which part is the most appropriate to be filled in the blank_____ so many people been out of work as today',
#   'options': ['Never before have',
#    'More than ever before',
#    'Formerly, there never were',
#    'In the past, there never have'],
#   'subject': 'Logical Reasoning',
#   'answer': 3},
#  {'id': 200,
#   'question': 'Read the following and choose the correct answer:“X, Y and Z are three whole numbers less than 31 but greater than 23. X is a prime number. Y is the largest odd number smaller than 35. Z is the smallest even number',
#   'options': ['X is 29, Y is 29 and Z is 24',
#    'X is 23, Y is 29 and Z is 24',
#    'X is 27, Y is 31 and Z is 26',
#    'X is 31, Y is 29 and Z is 24'],
#   'subject': 'Logical Reasoning',
#   'answer': 3}]
